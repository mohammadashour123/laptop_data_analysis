# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np 
import plotly.express as plx

# %%
data = pd.read_csv("laptop_data.csv")

# %%
data
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
data.drop("Unnamed: 0", axis = 1 , inplace= True)

# %%
data.sample()
# Out:
#     Company  TypeName  Inches   ScreenResolution                       Cpu  \
# 212      HP  Notebook    15.6  Full HD 1920x1080  Intel Core i3 6006U 2GHz
#
#      Ram     Memory                    Gpu  OpSys Weight     Price
# 212  4GB  500GB HDD  Intel HD Graphics 520  No OS  2.1kg  18594.72

# %%
# 8GB more pupular rams size 
data.Ram.value_counts()
# Out:
# 8GB     619
# 4GB     375
# 16GB    200
# 6GB      41
# 12GB     25
# 2GB      22
# 32GB     17
# 24GB      3
# 64GB      1
# Name: Ram, dtype: int64

# %%
data.Ram = data.Ram.str.replace("GB" , "")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
# astype 
# to_numeric 
data.Ram = data.Ram.astype("int")
# pd.to_numeric(data.Ram)

# %%
data.Ram.dtype
# Out:
# dtype('int32')

# %%
data.sample()
# Out:
#     Company            TypeName  Inches  \
# 502  Lenovo  2 in 1 Convertible    13.9
#
#                               ScreenResolution                         Cpu  \
# 502  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5 8250U 1.6GHz
#
#      Ram     Memory                     Gpu       OpSys Weight     Price
# 502    8  256GB SSD  Intel UHD Graphics 620  Windows 10  1.4kg  85194.72

# %%
data.Weight.value_counts()
# Out:
# 2.2kg     121
# 2.1kg      58
# 2.4kg      44
# 2.3kg      41
# 2.5kg      38
#          ...
# 3.25kg      1
# 4.7kg       1
# 1.55kg      1
# 1.18kg      1
# 4.0kg       1
# Name: Weight, Length: 179, dtype: int64

# %%
data.Weight.dtype
# Out:
# dtype('O')

# %%
data.Weight= data.Weight.str.replace("kg" , "")
data.Weight = data.Weight.astype("float")

# %%
data.Weight.dtype
# Out:
# dtype('float64')

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# ...

# %%
data.Company.value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
plx.bar( data , x = "Company" , y = "Price" , color= "Company")
# Out:
# <div>                            <div id="532a67f2-5a71-4294-bf17-88745b94bc16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("532a67f2-5a71-4294-bf17-88745b94bc16")) {                    Plotly.newPlot(                        "532a67f2-5a71-4294-bf17-88745b94bc16",                        [{"alignmentgroup":"True","hovertemplate":"Company=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"Apple","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Apple","offsetgroup":"Apple","orientation":"v","showlegend":true,"textposition":"auto","x":["Apple","Apple","Apple","Apple","Apple","Apple","Apple","Apple","Apple","Apple","Apple","Apple","Apple","Apple","Apple","Apple","Apple","Apple","Apple","Apple","Apple"],"xaxis":"x","y":[71378.6832,47895.5232,
# ...

# %%
plx.pie(data , names ="TypeName")
# Out:
# <div>                            <div id="4efeac6c-98b4-48d5-b739-e23bf8b6cdf3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4efeac6c-98b4-48d5-b739-e23bf8b6cdf3")) {                    Plotly.newPlot(                        "4efeac6c-98b4-48d5-b739-e23bf8b6cdf3",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"TypeName=%{label}<extra></extra>","labels":["Ultrabook","Ultrabook","Notebook","Ultrabook","Ultrabook","Notebook","Ultrabook","Ultrabook","Ultrabook","Ultrabook","Notebook","Notebook","Ultrabook","Notebook","Ultrabook","Ultrabook","Notebook","Ultrabook","Notebook","Ultrabook","Netbook","Gaming","Notebook","2 in 1 Convertible","Ultrabook","Notebook","Ultrabook","Notebook","Ultrabook","Notebook","Notebook","N
# ...

# %%
plx.line_3d(data , x = "Company" , y = "Price" , z = "Ram")
# Out:
# <div>                            <div id="05ca8e7d-f05c-4237-9000-6f19f1bae352" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05ca8e7d-f05c-4237-9000-6f19f1bae352")) {                    Plotly.newPlot(                        "05ca8e7d-f05c-4237-9000-6f19f1bae352",                        [{"hovertemplate":"Company=%{x}<br>Price=%{y}<br>Ram=%{z}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","scene":"scene","showlegend":false,"x":["Apple","Apple","HP","Apple","Apple","Acer","Apple","Apple","Asus","Acer","HP","HP","Apple","Dell","Apple","Apple","Dell","Apple","Lenovo","Dell","Asus","Lenovo","HP","Dell","HP","Dell","Apple","Dell","Dell","HP","Chuwi","Asus","HP","Dell","
# ...

# %%
plx.line(data , x = "Company" , y = "Price")
# Out:
# <div>                            <div id="76ee2b04-77b0-4963-8e00-e55b32a8acc4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76ee2b04-77b0-4963-8e00-e55b32a8acc4")) {                    Plotly.newPlot(                        "76ee2b04-77b0-4963-8e00-e55b32a8acc4",                        [{"hovertemplate":"Company=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["Apple","Apple","HP","Apple","Apple","Acer","Apple","Apple","Asus","Acer","HP","HP","Apple","Dell","Apple","Apple","Dell","Apple","Lenovo","Dell","Asus","Lenovo","HP","Dell","HP","Dell","Apple","Dell","Dell","HP","Chuwi","Asus","HP","Dell","Apple","Lenovo","Acer","Dell
# ...

# %%
data.sample()
# Out:
#      Company   TypeName  Inches   ScreenResolution  \
# 892  Samsung  Ultrabook    15.0  Full HD 1920x1080
#
#                             Cpu  Ram     Memory                    Gpu  \
# 892  Intel Core i7 7500U 2.7GHz    8  256GB SSD  Intel HD Graphics 620
#
#           OpSys  Weight     Price
# 892  Windows 10    1.17  90522.72

# %%
data.Cpu
# Out:
# 0                       Intel Core i5 2.3GHz
# 1                       Intel Core i5 1.8GHz
# 2                 Intel Core i5 7200U 2.5GHz
# 3                       Intel Core i7 2.7GHz
# 4                       Intel Core i5 3.1GHz
#                         ...
# 1298              Intel Core i7 6500U 2.5GHz
# 1299              Intel Core i7 6500U 2.5GHz
# 1300    Intel Celeron Dual Core N3050 1.6GHz
# 1301              Intel Core i7 6500U 2.5GHz
# 1302    Intel Celeron Dual Core N3050 1.6GHz
# Name: Cpu, Length: 1303, dtype: object

# %%
data["test"] = data.Cpu.str.split(" ").str[0:3]

# %%
data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
data['cpu name'] = data['Cpu'].apply(lambda x :" ".join(x.split()[0:3]))

# %%
data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
data.drop(["test" ,"" ] , axis = 1 , inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 data.drop(["test" , ] , axis = 1 , inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
data.drop(["Cpu"] , axis = 1 , inplace=True)

# %%
data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  Ram               Memory  \
# 0             IPS Panel Retina Display 2560x1600    8            128GB SSD
# 1                                       1440x900    8  128GB Flash Storage
# 2                              Full HD 1920x1080    8            256GB SSD
# 3             IPS Panel Retina Display 2880x1800   16            512GB SSD
# 4             IPS Panel Retina Display 2560x1600    8            256GB SSD
# ...

# %%
data.OpSys.value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
data.OpSys.unique()
# Out:
# array(['macOS', 'No OS', 'Windows 10', 'Mac OS X', 'Linux', 'Android',
#        'Windows 10 S', 'Chrome OS', 'Windows 7'], dtype=object)

# %%
mac_os = ["macOS" , "Mac OS X"]

def ops_name(x): 
    if x not in mac_os : 
        
        if x == "Linux" : 
            return "Linux"
        return "Windows"
        
    else : 
        return "Mac"

# %%
data.OpSys = data.OpSys.apply(ops_name)

# %%
data.OpSys.value_counts()
# Out:
# Windows    1220
# Linux        62
# Mac          21
# Name: OpSys, dtype: int64

# %%
data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  Ram               Memory  \
# 0             IPS Panel Retina Display 2560x1600    8            128GB SSD
# 1                                       1440x900    8  128GB Flash Storage
# 2                              Full HD 1920x1080    8            256GB SSD
# 3             IPS Panel Retina Display 2880x1800   16            512GB SSD
# 4             IPS Panel Retina Display 2560x1600    8            256GB SSD
# ...

# %%
data['gpu name'] = data['Gpu'].apply(lambda x :" ".join(x.split()[0:3]))

# %%
data.drop("Gpu" , axis = 1 , inplace=True)

# %%
data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  Ram               Memory  \
# 0             IPS Panel Retina Display 2560x1600    8            128GB SSD
# 1                                       1440x900    8  128GB Flash Storage
# 2                              Full HD 1920x1080    8            256GB SSD
# 3             IPS Panel Retina Display 2880x1800   16            512GB SSD
# 4             IPS Panel Retina Display 2560x1600    8            256GB SSD
# ...

# %%
data.Memory.value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
data["sec_memory"] = data.Memory.str.split("+").str[1]

# %%
data.test.value_counts()
# Out:
#   1TB HDD         185
#   2TB HDD          15
#   256GB SSD         3
#   500GB HDD         2
#   1.0TB Hybrid      2
#   512GB SSD         1
# Name: test, dtype: int64

# %%
data.test.unique()
# Out:
# array([nan, '  1TB HDD', '  256GB SSD', '  2TB HDD', '  500GB HDD',
#        '  512GB SSD', '  1.0TB Hybrid'], dtype=object)

# %%
data = data.rename(columns={'test': 'sec_memort'})

# %%
data["primary_memory"] =  data.Memory.str.split("+").str[0]

# %%
data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  Ram               Memory  \
# 0             IPS Panel Retina Display 2560x1600    8            128GB SSD
# 1                                       1440x900    8  128GB Flash Storage
# 2                              Full HD 1920x1080    8            256GB SSD
# 3             IPS Panel Retina Display 2880x1800   16            512GB SSD
# 4             IPS Panel Retina Display 2560x1600    8            256GB SSD
# ...

# %%
data.sec_memory = data.sec_memory.fillna("no avilable storage")

# %%
data.sec_memort.value_counts()
# Out:
# no avilable storage    1095
# 1TB HDD                 185
# 2TB HDD                  15
# 256GB SSD                 3
# 500GB HDD                 2
# 1.0TB Hybrid              2
# 512GB SSD                 1
# Name: sec_memort, dtype: int64

# %%
data.sec_memory = data.sec_memory.str.strip()

# %%
data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  Ram               Memory  \
# 0             IPS Panel Retina Display 2560x1600    8            128GB SSD
# 1                                       1440x900    8  128GB Flash Storage
# 2                              Full HD 1920x1080    8            256GB SSD
# 3             IPS Panel Retina Display 2880x1800   16            512GB SSD
# 4             IPS Panel Retina Display 2560x1600    8            256GB SSD
# ...

# %%
data.insert()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 data.insert("primary_memory" , 12)
#
# TypeError: DataFrame.insert() missing 1 required positional argument: 'value'

# %%
data.drop("sec_memort" , axis = 1 , inplace= True)

# %%
data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  Ram               Memory  \
# 0             IPS Panel Retina Display 2560x1600    8            128GB SSD
# 1                                       1440x900    8  128GB Flash Storage
# 2                              Full HD 1920x1080    8            256GB SSD
# 3             IPS Panel Retina Display 2880x1800   16            512GB SSD
# 4             IPS Panel Retina Display 2560x1600    8            256GB SSD
# ...

# %%
data.drop("Memory" , axis = 1 , inplace= True)

# %%
data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  Ram    OpSys  Weight  \
# 0             IPS Panel Retina Display 2560x1600    8      Mac    1.37
# 1                                       1440x900    8      Mac    1.34
# 2                              Full HD 1920x1080    8  Windows    1.86
# 3             IPS Panel Retina Display 2880x1800   16      Mac    1.83
# 4             IPS Panel Retina Display 2560x1600    8      Mac    1.37
# ...

# %%
data.ScreenResolution.value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
data['IPS'] = data['ScreenResolution'].apply(lambda x : 1 if 'IPS' in x else 0)
data['Touchscreen'] = data['ScreenResolution'].apply(lambda x : 1 if 'Touchscreen' in x else 0 )

# %%
data["extra_Screen"] = data.IPS + data.Touchscreen

# %%
data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  Ram    OpSys  Weight  \
# 0             IPS Panel Retina Display 2560x1600    8      Mac    1.37
# 1                                       1440x900    8      Mac    1.34
# 2                              Full HD 1920x1080    8  Windows    1.86
# 3             IPS Panel Retina Display 2880x1800   16      Mac    1.83
# 4             IPS Panel Retina Display 2560x1600    8      Mac    1.37
# ...

# %%
data.drop("ScreenResolution" , axis = 1, inplace= True)

# %%
data
# Out:
#      Company            TypeName  Inches  Ram    OpSys  Weight        Price  \
# 0      Apple           Ultrabook    13.3    8      Mac    1.37   71378.6832
# 1      Apple           Ultrabook    13.3    8      Mac    1.34   47895.5232
# 2         HP            Notebook    15.6    8  Windows    1.86   30636.0000
# 3      Apple           Ultrabook    15.4   16      Mac    1.83  135195.3360
# 4      Apple           Ultrabook    13.3    8      Mac    1.37   96095.8080
# ...      ...                 ...     ...  ...      ...     ...          ...
# 1298  Lenovo  2 in 1 Convertible    14.0    4  Windows    1.80   33992.6400
# 1299  Lenovo  2 in 1 Convertible    13.3   16  Windows    1.30   79866.7200
# 1300  Lenovo            Notebook    14.0    2  Windows    1.50   12201.1200
# 1301      HP            Notebook    15.6    6  Windows    2.19   40705.9200
# 1302    Asus            Notebook    15.6    4  Windows    2.20   19660.3200
#
# ...

# %%
data.TypeName.value_counts()
# Out:
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: TypeName, dtype: int64
